# %% [markdown]
# # 00 Explore the raw data
#
# Quick sanity check on the JSON in the UC volume: does it **read**, does the
# **schema** match expectations (especially for the nested deck arrays), is the **count**
# sensible, and does the **data** look real. Read-only.

# %%
RAW = "/Volumes/workspace/clash/raw"

# %% [markdown]
# ## Battles
#
# `battles.jsonl` is newline-delimited JSON, one per ingestion-batch folder.

# %%
battles = spark.read.json(f"{RAW}/*/battles.jsonl")
battles.printSchema()
# Out:
# root
#  |-- arena_id: long (nullable = true)
#  |-- arena_name: string (nullable = true)
#  |-- battle_id: string (nullable = true)
#  |-- battle_time: string (nullable = true)
#  |-- battle_time_raw: string (nullable = true)
#  |-- game_mode: string (nullable = true)
#  |-- ingested_at: string (nullable = true)
#  |-- is_ladder: boolean (nullable = true)
#  |-- opponent_cards: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- opponent_crowns: long (nullable = true)
#  |-- opponent_deck_hash: string (nullable = true)
#  |-- opponent_name: string (nullable = true)
#  |-- opponent_starting_trophies: long (nullable = true)
#  |-- opponent_tag: string (nullable = true)
#  |-- opponent_trophy_change: long (nullable = true)
#  |-- player_cards: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- player_crowns: long (nullable = true)
#  |-- player_deck_hash: string (nullable = true)
#  |-- player_name: string (nullable = true)
#  |-- player_starting_trophies: long (nullable = true)
#  |-- player_tag: string (nullable = true)
#  |-- player_trophy_change: long (nullable = true)
#  |-- source_player_tag: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- win: boolean (nullable = true)

# %%
print(battles.count(), "battle rows")
# Out:
# 317467 battle rows

# %%
display(battles.limit(80))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>arena_id</th><th>arena_name</th><th>battle_id</th><th>battle_time</th><th>battle_time_raw</th><th>game_mode</th><th>ingested_at</th><th>is_ladder</th><th>opponent_cards</th><th>opponent_crowns</th><th>opponent_deck_hash</th><th>opponent_name</th><th>opponent_starting_trophies</th><th>opponent_tag</th><th>opponent_trophy_change</th><th>player_cards</th><th>player_crowns</th><th>player_deck_hash</th><th>player_name</th><th>player_starting_trophies</th><th>player_tag</th><th>player_trophy_change</th><th>source_player_tag</th><th>type</th><th>win</th></tr></thead><tbody><tr><td>54000152</td><td>Legendary Arena</td><td>b358ef63d347de62a1f4ff7bc6321e1c84a0ab06</td><td>2026-06-02T15:11:59+00:00</td><td>20260602T151159.000Z</td><td>Showdown_Friendly</td><td>2026-06-02T15:13:42.076381+00:00</td><td>false</td><td>List(26000049, 26000062, 26000058, 27000004, 26000032, 26000031, 26000010, 28000011)</td><td>1</td><td>acc944057539d5b5c252869f3a2a655a4f9ac0de</td><td>SXRGIO™</td><td>null</td><td>#C99JJRQUR</td><td>null</td><td>List(26000012, 26000069, 26000022, 26000056, 26000040, 26000019, 26000053, 28000001)</td><td>0</td><td>69c81375c702b4b55efc0db072d2114a8ccc633a</td><td>アスダシアス</td><td>null</td><td>#2GURR8VLP</td><td>null</td><td>#2GURR8VLP</td><td>trail</td><td>false</td></tr><tr><td>54000152</td><td>Legendary Arena</td><td
td><td>14000</td></tr><tr><td>#QVL92090</td><td>Javav</td><td>#92LRCVUY</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Jerry</td><td>#PCPUU8Y8Y</td><td>14000</td></tr><tr><td>#QVL92090</td><td>YodaBear</td><td>#2YVJVQUJR</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Jay</td><td>#JP0G02</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Lui</td><td>#YLJL0JP</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Parsa</td><td>#8LGVU09Y</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Yae</td><td>#RY9J2VCPQ</td><td>14000</td></tr><tr><td>#QVL92090</td><td>MacDonald81</td><td>#GC2UJ0G</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Combatiente</td><td>#8UPYRCYU</td><td>14000</td></tr><tr><td>#QVL92090</td><td>futuredilf</td><td>#RJ8LV0UQ</td><td>14000</td></tr><tr><td>#QVL92090</td><td>JP</td><td>#UPUC0QVQC</td><td>14000</td></tr><tr><td>#QVL92090</td><td>Zayats</td><td>#PVQUL2YRL</td><td>14000</td></tr><tr><td>#QVL92090</td><td>John "Foxy" Red</td><td>#LGRR2Y9Q</td><td>14000</td></tr><tr><td>#QVL92090</td><td>nakala12</td><td>#CG2LJU0G</td><td>14000</td></tr><tr><td>#QVL92090</td><td>AujlLa</td><td>#L9VQGRYGU</td><td>14000</td></tr><tr><td>#QVL92090</td><td>cradle004</td><td>#UYU9JY0U2</td><td>14000</td></tr><tr><td>#QVL92090</td><td>5pike</td><td>#9RVLU8CRL</td><td>14000</td></tr><tr><td>#QVL92090</td><td>xloxu</td><td>#V2JY0YCVV</td><td>14000</td></tr><tr><td>#QVL92090</td><td>DarkzShadows12</td><td>#Q09CVLLP</td><td>14000</td></tr></tbody></table></div>

# %% [markdown]
# ## Cards

# %%
cards = spark.read.option("multiline", "true").json(f"{RAW}/cards.json")
cards.printSchema()
print(cards.count(), "cards")
display(cards.orderBy("card_id"))
# Out:
# root
#  |-- card_id: long (nullable = true)
#  |-- elixir_cost: long (nullable = true)
#  |-- max_level: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- rarity: string (nullable = true)
#
# 121 cards
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>card_id</th><th>elixir_cost</th><th>max_level</th><th>name</th><th>rarity</th></tr></thead><tbody><tr><td>26000000</td><td>3</td><td>16</td><td>Knight</td><td>common</td></tr><tr><td>26000001</td><td>3</td><td>16</td><td>Archers</td><td>common</td></tr><tr><td>26000002</td><td>2</td><td>16</td><td>Goblins</td><td>common</td></tr><tr><td>26000003</td><td>5</td><td>14</td><td>Giant</td><td>rare</td></tr><tr><td>26000004</td><td>7</td><td>11</td><td>P.E.K.K.A</td><td>epic</td></tr><tr><td>26000005</td><td>3</td><td>16</td><td>Minions</td><td>common</td></tr><tr><td>26000006</td><td>5</td><td>11</td><td>Balloon</td><td>epic</td></tr><tr><td>26000007</td><td>5</td><td>11</td><td>Witch</td><td>epic</td></tr><tr><td>26000008</td><td>5</td><td>16</td><td>Barbarians</td><td>common</td></tr><tr><td>26000009</td><td>8</td><td>11</td><td>Golem</td><td>epic</td></tr><tr><td>26000010</td><td>1</td><td>16</td><td>Skeletons</td><td>common</td></tr><tr><td>26000011</td><td>4</td><td>14</td><td>Valkyrie</td><td>rare</td></tr><tr><td>26000012</td><td>3</td><td>11</td><td>Skeleton Army</td><td>epic</td></